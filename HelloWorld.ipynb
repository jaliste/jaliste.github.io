# %% [markdown]
# Esto es una prueba
# ==========
#
# Podemos usar latex en estos archivos. $\nabla u = 0$

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,10,100)
plt.plot(np.sin(x))
